# %%
m1 = 5
v1 = 3
m2 = 3
v2 = 1

p = (m1*v1-m2*v2)
dU = 0.5*m1*v1**2 + 0.5*m2*v2**2 - p**2/(2*(m1+m2))
print(p,dU)
# Out:
# 12 15.0

# %%
from sympy import *
m = 0.3
T = 0 + 273.15
l = 333.5*1000
c = 4184

dS = m*l/T
print(dS)

dT = 20
dS2 = m*c*log((T+dT)/T)
print(dS2)

Q1 = m*l
Q2 = c*m*dT
Q = Q1+Q2
print(Q)
# Out:
# 366.28226249313565
# 88.6966100191780
# 125154.0

# %%
V = 3e5
nO2 = 10**3
nHe = 9*10**3
T = 20+273.15
R = 0.08206

P = (nO2+nHe)*R*T/V
print(P)

dT = 10
r = 8.314
CO2 = 5/2*r
CHe = 3/2*r

Q1 = CO2*nO2*dT
Q2 = CHe*nHe*dT
print(Q1+Q2)
# Out:
# 0.8018629666666666
# 1330240.0

# %%
m = 4.65*10**(-26)
g = 9.8
h = 10**3
T = 250
kB = 1.38*10**(-23)
P1 = exp(-m*g*h/(kB*T))
P2 = exp(-m*g*(h/2)/(kB*T))
ans = P1/P2
print(ans)
# Out:
# 0.936090163834492

# %%
T = 250
kB = 1.38*10**(-23)
E1 = 0
E2 = 1.6*10**(-21)
E3 = E2

avg = (E1*exp(-E1/(kB*T))+E2*exp(-E2/(kB*T))+E3*exp(-E3/(kB*T)))/(exp(-E1/(kB*T))+exp(-E2/(kB*T))+exp(-E3/(kB*T)))
print(avg)
# Out:
# 8.91351440502344e-22

# %%
n = 2
T = 290
V1 = 2
V2 = 1
R = 8.314

W = n*R*T*log(V2/V1)
print(W)
# Out:
# -3342.43888232172

# %%
nHe = 3e23
He = 4
N2 = 28

ans = sqrt(N2)/sqrt(He)
print(ans.evalf())
# Out:
# 2.64575131106459

# %%
R = 8.314
C = 3*R
m = 500
M = 107
n = m/M
Q = 300

dT = Q/(C*n)
print(dT)
# Out:
# 2.573971614144816

# %%
dT = 40
ans = 0.9*(250-290)
print(ans)
# Out:
# -36.0

# %%
mcopper = 0.3
nhe = 1.5
The = 123+273.15
Tcopper = 20+273.15

ccopper =386
chelium = 12.5
T = symbols('T')
ans = solve(ccopper*mcopper*(T-Tcopper)-chelium*nhe*(The-T),T)
print(ans)
# Out:
# [307.503400222965]

# %%
E1 = 2.1*10**(-21)
E2 = 1*10**(-21)
T = 246
P = exp((-E1/(kB*T)))/(exp((-E1/(kB*T)))+exp(-E2/(kB*T)))
print(P)
# Out:
# 0.419695143942364
