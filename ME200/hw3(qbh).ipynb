# %%
import numpy as np

T_initial = -20.0000 # °C
x_initial = 0.5036 # 
P_final = 6.0000 # bar       # Pa
vf=0.0007427
vg=0.0926
v1=vf+x_initial*(vg-vf)
T_final=40+5*(v1-0.04628)/(0.04724-0.04628)
print(T_final)
# Out:
# 43.76060562500004

# %%
import numpy as np

P_initial = 200.00 # lbf/in$^2$
x_initial = 0.80 # 
T_final = 480.00 # °F

# 饱和物性 (200 lbf/in²)
v_f =  0.01839    # ft³/lb
v_g =  2.289       # ft³/lb

# 初始比容
v1 = v_f + x_initial * (v_g - v_f)

# 最终比容 (200 lbf/in², 480°F 过热蒸汽)
v2 = 2.548+30/50*(2.724-2.548)         # ft³/lb

# 定压功计算 (单位转换: lbf/in² -> lbf/ft², ft·lbf -> Btu)
w_ftlbf = P * 144 * (v2 - v1)
w_btu = w_ftlbf / 778

print(f"初始比容 v1 = {v1:.4f} ft³/lb")
print(f"最终比容 v2 = {v2:.4f} ft³/lb")
print(f"单位质量功 w = {w_btu:.2f} Btu/lb")
# Out:
# 初始比容 v1 = 1.8349 ft³/lb
# 最终比容 v2 = 2.6536 ft³/lb
# 单位质量功 w = 30.31 Btu/lb

# %%
P_ini
# Out:
# 13.78952

# %%
import numpy as np

p_1 = 200.0000 # lbf/in^2
T_1 = 200.0000 # F
W = -88.8400 # Btu
m = 7.0000 # lb

delta_v=W*778/144/p_1
v=0.7025  # ft³/lb

Vini=7*v
Vafter=Vini+delta_v
v1=0.03432
v2=0.5261
vreal=Vafter/7
x=(vreal-v1)/(v2-v1)
print(x)
# Out:
# 0.6615461359350905
