# %%
#1
import numpy as np
a = 0.1
b = 1.1
c = 0.2
f1 = 2
f2 = 7
f3 = 9
f4 = 4

f = f1 + f3 - f2 -f4
print(f)
sigma_a = f1/(np.pi*a**2/4)
sigma_b = -(f3-f4)/(np.pi*b**2/4)
sigma_c = f4/(np.pi*c**2/4)
print(sigma_a,sigma_b,sigma_c)
# Out:
# 0
# 254.64790894703253 -5.261320432789928 127.32395447351627

# %%
#2
import numpy as np
f1 = 8
f2 = 13
f3 = 2
f4 = 13
f5 = 27

# f1,f3,f5连在墙上所以不算
# f2,f4选最大的/2 因为两面

# %%
#3
from scipy.integrate import quad
import numpy as np

P = quad(lambda x: 15*x**0.5, 0, 4)[0]
m = quad(lambda x: 15*x**1.5, 0, 4)[0]

d = m/P
P*9, d
# Out:
# (719.9999999999999, 2.399999999983377)

# %%
#4
d = 15/1000
F = 29*1000
t = 18/1000

normal_stress = F/(d*t)
shear_stress = F/(np.pi*d**2/4)
normal_stress/10**6, shear_stress/10**6
# Out:
# (107.40740740740743, 164.10643021030987)

# %%
#5
a = 50
b = 21
FS = 1.5
failure_stress = 50
w = 0.5

allow_stress = failure_stress/FS
h2 = (2*b+a)/allow_stress/w
h1 = (a)/allow_stress/w
h1, h2
# Out:
# (3.0, 5.52)

# %%
#6
a = 10
b = 14
c = 2
l = 11
F = 22

normal_stress = F/(c*b)*1000
shear_stress = F/(l*b)*1000
normal_stress, shear_stress
# Out:
# (785.7142857142857, 142.85714285714286)

# %%
#7
F = 80000
failure_shear_stress = 390
FS = 2.6
allow_shear_stress = failure_shear_stress/FS
d = np.sqrt(4* F/2/2 / allow_shear_stress / np.pi)
d
# Out:
# 13.029400317411199

# %%
#8
ab = 0.23
be = 0.035
ce = 0.035

G = 3.4*9.81

fy = G*(ab+be+ce)/(ce+be)
N_E = -fy/np.tan(np.radians(75))
V_E = -(fy - G)
M_E = fy*be - G*(be+ab)
N_E, V_E, M_E
# Out:
# (-38.302188704347145, -109.5917142857143, -3.8357099999999997)

# %%
#9
FS = 3
Ff = 905
Fa = Ff/FS
Fa
# Out:
# 301.6666666666667

# %%
#10
L = 619
theta = np.radians(3)
L2 = 2*np.sin((theta+np.pi/2)/2)*L/np.sqrt(2)
e = (L2-L) / L
e
#余弦定理也可以
# Out:
# np.float64(0.025834273283430444)
